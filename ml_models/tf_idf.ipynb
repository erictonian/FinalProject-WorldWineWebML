# %%
# import dependencies
import numpy as np
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import string

# %%
# import the data
data = pd.read_csv("../output_data/final_wine_data_172k_clean.csv")
data.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 1           2        US  Tart and snappy, the flavors of lime flesh and...
# 2           3        US  Pineapple rind, lemon pith and orange blossom ...
# 3           4        US  Much like the regular bottling from 2012, this...
# 4           5     Spain  Blackberry and raspberry aromas show a typical...
#
#                           designation  points  price        province  \
# 0                            Avidagos      87   15.0           Douro
# 1                                 NaN      87   14.0          Oregon
# 2                Reserve Late Harvest      87   13.0        Michigan
# 3  Vintner's Reserve Wild Child Block      87   65.0          Oregon
# 4                        Ars In Vitro      87   15.0  Northern Spain
#
#               region_1           region_2         taster_name  \
# 0                  NaN                NaN          Roger Voss
# 1    Willamette Valley  Willamette Valley        Paul Gregutt
# 2  Lake Michigan Shore                NaN  Alexander Peartree
# 3    Willamette Valley  Willamette Valley        Paul Gregutt
# 4              Navarra                NaN   Michael Schachner
#
#   taster_twitter_handle                                              title  \
# 0            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 1           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 2                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 3           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
# 4           @wineschach  Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
#
#               variety               winery  \
# 0      Portuguese Red  Quinta dos Avidagos
# 1          Pinot Gris            Rainstorm
# 2            Riesling           St. Julian
# 3          Pinot Noir         Sweet Cheeks
# 4  Tempranillo-Merlot               Tandem
#
#                                        descrip_clean  \
# 0  This is ripe and fruity a wine that is smooth ...
# 1  Tart and snappy the flavors of lime flesh and ...
# 2  Pineapple rind lemon pith and orange blossom s...
# 3  Much like the regular bottling from 2012 this ...
# 4  Blackberry and raspberry aromas show a typical...
#
#                                   descript_tokenized  \
# 0  ['this', 'is', 'ripe', 'and', 'fruity', 'a', '...
# 1  ['tart', 'and', 'snappy', 'the', 'flavors', 'o...
# 2  ['pineapple', 'rind', 'lemon', 'pith', 'and', ...
# 3  ['much', 'like', 'the', 'regular', 'bottling',...
# 4  ['blackberry', 'and', 'raspberry', 'aromas', '...
#
#                                      discript_nostop  \
# 0  ['ripe', 'fruity', 'wine', 'smooth', 'still', ...
# 1  ['tart', 'snappy', 'flavors', 'lime', 'flesh',...
# 2  ['pineapple', 'rind', 'lemon', 'pith', 'orange...
# 3  ['much', 'like', 'regular', 'bottling', '2012'...
# 4  ['blackberry', 'raspberry', 'aromas', 'show', ...
#
#                                  descript_lemmatized
# 0  ['ripe', 'fruity', 'wine', 'smooth', 'still', ...
# 1  ['tart', 'snappy', 'flavor', 'lime', 'flesh', ...
# 2  ['pineapple', 'rind', 'lemon', 'pith', 'orange...
# 3  ['much', 'like', 'regular', 'bottling', '2012'...
# 4  ['blackberry', 'raspberry', 'aroma', 'show', '...

# %%
data = data.filter(["price", "descript_lemmatized"], axis = 1)

# %%
data.head()
# Out:
#    price                                descript_lemmatized
# 0   15.0  ['ripe', 'fruity', 'wine', 'smooth', 'still', ...
# 1   14.0  ['tart', 'snappy', 'flavor', 'lime', 'flesh', ...
# 2   13.0  ['pineapple', 'rind', 'lemon', 'pith', 'orange...
# 3   65.0  ['much', 'like', 'regular', 'bottling', '2012'...
# 4   15.0  ['blackberry', 'raspberry', 'aroma', 'show', '...

# %% [markdown]
# # Apply TfidfVectorizer

# %%
tfidf_vect = TfidfVectorizer()
X_tfidf = tfidf_vect.fit_transform(data['descript_lemmatized'])
print(X_tfidf.shape)
print(tfidf_vect.get_feature_names())
# Out:
# (171059, 41353)
# ['01', '02', '03', '04', '04s', '05', '053', '05s', '06', '06s', '07', '07acre', '07s', '08', '081199', '08s', '09', '09s', '0degree', '10', '100', '1000', '10000', '100000', '100000case', '100000plus', '1000acre', '1000feet', '1000foot', '1000footelevation', '1000liter', '100acre', '100case', '100dijonclone', '100gl', '100ml', '100organic', '100percent', '100plusyearold', '100point', '100th', '100varietal', '100year', '100yearold', '100years', '100yearsold', '101', '1015', '1016', '102', '1030feet', '103acre', '103years', '104', '105', '105gl', '106', '10600', '106yearold', '107', '107th', '108', '108acre', '10acre', '10gl', '10plus', '10spot', '10th', '10year', '10yearaged', '10yearold', '10years', '10yearsold', '11', '110', '1100', '11000', '110000', '1100feet', '110414', '110acre', '111', '111000', '1110feet', '1110foothigh', '111acre', '112', '113', '113acre', '114', '115', '1150', '115000', '116', '11600', '116acre', '117', '119', '1194', '11acre', '11th', '11vineyard', '11year', '11yearold', '12', '120', '1200', '12000', '1200feet', '1200foot', '1200liter', '120plus', '120yearold', '120yearsold', '12100', '122', '122acre', '123', '123acre', '124', '125', '1250', '12500', '125000', '1252', '125acre', '126', '127', '12700', '1275', '128', '1280', '129', '1290', '12acre', '12alcohol', '12barrel', '12gl', '12months', '12th', '12thcentury', '12yearold', '13', '130', '1300', '13000', '130000', '1300feet', '1300foot', '1300foothigh', '13025', '130acre', '130gallon', '130th', '130yearold', '131', '131yearold', '132', '13200', '132gallon', '133', '134', '134000', '1346', '135', '1350', '13500', '1350acre', '135acre', '136', '136000', '137', '1375', '138', '139', '1396', '13acre', '13gl', '13th', '13thcentury', '13yearold', '13yearsold', '14', '140', '1400', '14000', '140000', '1400elevation', '1400feet', '1400foot', '1400foothigh', '141', '142', '1429', '143', '144', '145', '1450', '146', '147', '1470', '147acre', '148', '149', '1492', '14acre', '14gl', '14th', '14thcentury', '14year', '14yearold', '15', '150', '1500', '15000', '150000', '1500acre', '1500feet', '1500foot', '1500s', '150th', '151', '1513', '152', '153', '1537', '154', '155', '155gl', '156', '157', '158', '159', '159gl', '15acre', '15generation', '15gl', '15l', '15th', '15thcentury', '15yearold', '15yearsold', '16', '160', '1600', '16000', '160000', '1600feet', '16056', '1607', '160acre', '160gl', '161', '1610', '1619', '162', '1628', '163', '16300', '164', '1640', '1649', '165', '16500', '1650feetelevation', '165acre', '166', '16663', '1667', '166th', '167', '168', '1685', '1690', '1692', '16acre', '16gl', '16th', '16thcentury', '16yearold', '17', '170', '1700', '17000', '170000', '1700feet', '1700s', '170gl', '171', '1724', '172acres', '17300', '1737', '1739', '1740', '1744', '175', '17500', '1752', '1756', '1759', '1763', '177', '1772', '1779', '177acre', '1780', '17843', '1787', '1789', '179', '1790', '1790s', '1791', '17acre', '17th', '17thcentury', '17yearold', '18', '180', '1800', '18000', '1800feet', '1800foot', '1800foothigh', '1800s', '1806', '1811', '1819', '1820s', '1829', '183', '1830s', '1834', '1835', '1836', '1837', '1839', '184', '1840s', '1843', '1844', '1846', '1847', '185', '1850', '1850s', '1851', '1853', '1854', '1855', '1856', '1858', '1859', '186', '1860s', '1864', '1865', '1868', '1869', '1870', '1871', '1873', '1875', '1877', '1878', '187ml', '1880s', '1881', '1882', '1888', '1889', '188th', '1890', '1890s', '1892', '1893', '1894', '1895', '189gl', '18acre', '18month', '18th', '18thcentury', '18wheeler', '18yearold', '19', '1900', '19000', '190000', '1900feet', '1901', '1902', '1903', '1904', '1905', '1906', '1908', '1909', '191', '1910', '1912', '1913', '1914', '1915', '1917', '1918', '1919', '1920', '1920s', '1920sstyle', '1922', '1924', '1925', '1926', '1927', '1928', '1929', '1930', '1930s', '1933', '1934', '1935', '1936', '1937', '1938', '1939', '1940', '1940s', '1944', '1945', '1946', '1947', '1948', '1949', '194gl', '195', '1950',  ...
